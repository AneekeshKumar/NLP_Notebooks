# %% [markdown]
# # Installing the libraries

# %%
# ! pip install pandas
# ! pip install numpy
# ! pip install matplotlib
# ! pip install seaborn

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # creating subplots and formating figures
import seaborn as sns # visualizations including heatmaps
# %matplotlib inline

# %% [markdown]
# # Importing the Dataset

# %%
df = pd.read_csv(r"C:\Users\sraja\Downloads\sales_data_sample.csv")
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#         STATUS  QTR_ID  MONTH_ID  YEAR_ID PRODUCTLINE  ...           PHONE  \
# 2818   Shipped       4        12     2004       Ships  ...  (91) 555 94 44
# 2819   Shipped       1         1     2005       Ships  ...      981-443655
# 2820  Resolved       1         3     2005       Ships  ...  (91) 555 94 44
# 2821   Shipped       1         3     2005       Ships  ...      61.77.6555
# 2822   On Hold       2         5     2005       Ships  ...      6175559555
#
#                ADDRESSLINE1 ADDRESSLINE2      CITY POSTALCODE  COUNTRY  \
# ...

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(x ='STATUS',y='SALES', data = df)
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='SALES'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x ='STATUS',y='SALES', hue = 'PRODUCTLINE', data = df)
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='SALES'>

# %% [markdown]
# # Horizontal Barplot

# %%
sns.barplot(x ='SALES',y='STATUS',capsize= 0.2, data = df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='STATUS'>

# %% [markdown]
# # Lineplot

# %%
sns.lineplot(x='MONTH_ID', y= 'SALES', data=df)
# Out:
# <AxesSubplot:xlabel='MONTH_ID', ylabel='SALES'>

# %% [markdown]
# ## Without Confidence Interval

# %%
sns.lineplot(x='MONTH_ID', y= 'SALES', ci = None, data=df)
# Out:
# <AxesSubplot:xlabel='MONTH_ID', ylabel='SALES'>

# %% [markdown]
# ## Tweaking the CI

# %%
sns.lineplot(x='MONTH_ID', y= 'SALES', ci = 'sd', data=df)
# Out:
# <AxesSubplot:xlabel='MONTH_ID', ylabel='SALES'>

# %% [markdown]
# ## With estimator

# %%
sns.lineplot(x='MONTH_ID', y= 'SALES', ci = None, estimator= sum, data=df)
# Out:
# <AxesSubplot:xlabel='MONTH_ID', ylabel='SALES'>

# %%
sns.lineplot(x='MONTH_ID', y= 'SALES', ci = None, estimator= None , data=df)
# Out:
# <AxesSubplot:xlabel='MONTH_ID', ylabel='SALES'>

# %% [markdown]
# ## Grouping the Lineplot

# %%
sns.lineplot(x='MONTH_ID', y= 'SALES', ci = None, hue= 'YEAR_ID', data=df)
# Out:
# <AxesSubplot:xlabel='MONTH_ID', ylabel='SALES'>

# %%
sns.lineplot(x='MONTH_ID', y= 'SALES', ci = None, hue= 'YEAR_ID',palette = 'dark:salmon_r', data=df)
# Out:
# <AxesSubplot:xlabel='MONTH_ID', ylabel='SALES'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x='STATUS', y='SALES', data=df)
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='SALES'>

# %%
sns.boxplot(x='STATUS', y='SALES', showmeans= True, data=df)
# Out:
# <AxesSubplot:xlabel='STATUS', ylabel='SALES'>

# %% [markdown]
# # Histogram

# %%
sns.histplot(x='SALES',data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='Count'>

# %% [markdown]
# ## Binwidth

# %%
sns.histplot(x='SALES',binwidth=600,data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='Count'>

# %% [markdown]
# ## Adjusting the Histogram

# %%
sns.histplot(x='SALES',bins= np.arange(0,14000,1000), data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='Count'>

# %% [markdown]
# ## Frequency Line

# %%
sns.histplot(x='SALES',bins= np.arange(0,14000,1000),kde= True, data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='Count'>

# %% [markdown]
# ## Polyplot Histogram

# %%
sns.histplot(x='SALES',element ='poly',data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='Count'>

# %%
sns.histplot(x='SALES',stat= 'probability', data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='Probability'>

# %% [markdown]
# # Scatterplot

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='SALES',y= 'PRICEEACH', data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='PRICEEACH'>

# %% [markdown]
# ## Grouping the Scatterplot

# %%
sns.scatterplot(x='SALES',y= 'PRICEEACH', hue= 'YEAR_ID', data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='PRICEEACH'>

# %% [markdown]
# ## With Markers

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='SALES',y= 'PRICEEACH', style = 'YEAR_ID', size= 'ORDERLINENUMBER', data= df)
# Out:
# <AxesSubplot:xlabel='SALES', ylabel='PRICEEACH'>

# %% [markdown]
# # Heatmap

# %%
df2= df.pivot_table(index='STATUS',columns='PRODUCTLINE',values='SALES')
df2
df2.fillna(0)
# Out:
# PRODUCTLINE  Classic Cars  Motorcycles       Planes        Ships     Trains  \
# STATUS
# Cancelled     3702.675625     0.000000  2952.725833  3148.091667  5082.4200
# Disputed      8670.956667  5303.650000  1921.920000  3070.400000     0.0000
# In Process    4125.761429     0.000000     0.000000     0.000000     0.0000
# On Hold       4086.637500  4992.610000  3858.614444  2958.076250  5808.4800
# Resolved      3224.917500     0.000000  2877.743333  3321.975833     0.0000
# Shipped       4050.066007  3486.338981  3197.293616  3031.655179  2871.3676
#
# PRODUCTLINE  Trucks and Buses  Vintage Cars
# STATUS
# Cancelled            0.000000   2927.991538
# Disputed             0.000000   3731.925000
# In Process        3911.491818   2746.430625
# On Hold           5048.322500   4505.891111
# Resolved          4094.550000   3004.956000
# Shipped           3715.649075   3129.403285

# %%
sns.set_style('white')
plt.figure(figsize=(5,5))
sns.heatmap(df2)
# Out:
# <AxesSubplot:xlabel='PRODUCTLINE', ylabel='STATUS'>

# %% [markdown]
# # With Numbers in cell

# %%
sns.heatmap(df2,annot=True)
# Out:
# <AxesSubplot:xlabel='PRODUCTLINE', ylabel='STATUS'>

# %% [markdown]
# # Integers

# %%
sns.heatmap(df2,annot=True,fmt='.0f')
# Out:
# <AxesSubplot:xlabel='PRODUCTLINE', ylabel='STATUS'>

# %% [markdown]
# # Numbers Styling

# %%
sns.heatmap(df2,annot=True,fmt='.0f',annot_kws= dict(size=15,weight='bold'),linewidths=0.5)
# Out:
# <AxesSubplot:xlabel='PRODUCTLINE', ylabel='STATUS'>

# %%
df2.corr()
# Out:
# PRODUCTLINE       Classic Cars  Motorcycles    Planes     Ships    Trains  \
# PRODUCTLINE
# Classic Cars          1.000000     0.637445 -0.758043 -0.294264 -0.196335
# Motorcycles           0.637445     1.000000 -0.335136 -0.016474  1.000000
# Planes               -0.758043    -0.335136  1.000000 -0.339786  0.478723
# Ships                -0.294264    -0.016474 -0.339786  1.000000 -0.109870
# Trains               -0.196335     1.000000  0.478723 -0.109870  1.000000
# Trucks and Buses      0.118480     1.000000  0.822733 -0.422748  1.000000
# Vintage Cars          0.335584     0.727529  0.334367 -0.705717  0.601715
#
# PRODUCTLINE       Trucks and Buses  Vintage Cars
# PRODUCTLINE
# Classic Cars              0.118480      0.335584
# Motorcycles               1.000000      0.727529
# Planes                    0.822733      0.334367
# Ships                    -0.422748     -0.705717
# Trains                    1.000000      0.601715
# Trucks and Buses          1.000000      0.927396
# ...

# %%
sns.heatmap(df2.corr(),vmin=-1,vmax=1)
# Out:
# <AxesSubplot:xlabel='PRODUCTLINE', ylabel='PRODUCTLINE'>

# %%
sns.heatmap(df2.corr(),vmin=-1,vmax=1,annot=True,fmt='.1f')
# Out:
# <AxesSubplot:xlabel='PRODUCTLINE', ylabel='PRODUCTLINE'>
